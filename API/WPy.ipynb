# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from datetime import datetime
from random import uniform

# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)

# %%
# Randomly generate a list of 1750 cities. Use 50 to test for duplicates.
for x in range(1750):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      713
# City       713
# Country    713
# dtype: int64

# %%
#Create a df to add all the data from the API calls.
column_names = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)

# Loop through the list of cities and add the data to the df.
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + "ec8ce9ae3ae7d672b2fe520eb9895eed" + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        clean_cities_df.set_value(index, "City", city_data["name"])
        clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  1  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  2  |  Mount Gambier AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mount+gambier
# City not found, skipping...
# ------------------------
# Proceesing: City #  3  |  Isla Mujeres MX
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=isla+mujeres
# ------------------------
# Proceesing: City #  4  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  5  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=provideniya
# City not found, skipping...
# ------------------------
# Proceesing: City #  6  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  7  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tuatapere
# ------------------------
# Proceesing: City #  8  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  9  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=saint-philippe
# City not found, skipping...
# ------------------------
# Proceesing: City #  10  |  Russell AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=russell
# City not found, skipping...
# ------------------------
# Proceesing: City #  11  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  12  |  Krasni Okny UA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=krasni+okny
# ------------------------
# Proceesing: City #  13  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  14  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  15  |  Cap Malheureux MU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cap+malheureux
# ------------------------
# Proceesing: City #  16  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cidreira
# City not found, skipping...
# ------------------------
# Proceesing: City #  17  |  Den Chai TH
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=den+chai
# ------------------------
# Proceesing: City #  18  |  Espanola CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=espanola
# City not found, skipping...
# ------------------------
# Proceesing: City #  19  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  20  |  Bud NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=bud
# ------------------------
# Proceesing: City #  21  |  Gaillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=gaillac
# ------------------------
# Proceesing: City #  22  |  Ridgecrest US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ridgecrest
# ------------------------
# Proceesing: City #  23  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=rikitea
# City not found, skipping...
# ------------------------
# Proceesing: City #  24  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  25  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  26  |  Codrington AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=codrington
# ------------------------
# Proceesing: City #  27  |  Solnechnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=solnechnyy
# ------------------------
# Proceesing: City #  28  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  29  |  Naryan-Mar RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=naryan-mar
# ------------------------
# Proceesing: City #  30  |  Vila Velha BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=vila+velha
# ------------------------
# Proceesing: City #  31  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  32  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hasaki
# ------------------------
# Proceesing: City #  33  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=vostok
# ------------------------
# Proceesing: City #  34  |  Mareeba AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mareeba
# ------------------------
# Proceesing: City #  35  |  Mbanza-Ngungu CD
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mbanza-ngungu
# ------------------------
# Proceesing: City #  36  |  Atikokan CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=atikokan
# ------------------------
# Proceesing: City #  37  |  Buraydah SA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=buraydah
# ------------------------
# Proceesing: City #  38  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mataura
# City not found, skipping...
# ------------------------
# Proceesing: City #  39  |  Oksfjord NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=oksfjord
# ------------------------
# Proceesing: City #  40  |  Koshurnikovo RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=koshurnikovo
# ------------------------
# Proceesing: City #  41  |  Meulaboh ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=meulaboh
# ------------------------
# Proceesing: City #  42  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  43  |  Mehamn NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mehamn
# ------------------------
# Proceesing: City #  44  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=esperance
# ------------------------
# Proceesing: City #  45  |  Songea TZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=songea
# ------------------------
# Proceesing: City #  46  |  San Cristobal EC
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=san+cristobal
# ------------------------
# Proceesing: City #  47  |  Lompoc US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=lompoc
# ------------------------
# Proceesing: City #  48  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  49  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  50  |  Lata IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=lata
# ------------------------
# Proceesing: City #  51  |  Kruisfontein ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kruisfontein
# ------------------------
# Proceesing: City #  52  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  53  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=arraial+do+cabo
# ------------------------
# Proceesing: City #  54  |  Lorengau PG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=lorengau
# ------------------------
# Proceesing: City #  55  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  56  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=vaini
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  57  |  Lagoa PT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=lagoa
# ------------------------
# Proceesing: City #  58  |  Srandakan ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=srandakan
# ------------------------
# Proceesing: City #  59  |  Jilin CN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=jilin
# ------------------------
# Proceesing: City #  60  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  61  |  Boa Vista BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=boa+vista
# ------------------------
# Proceesing: City #  62  |  Malidong PH
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=malidong
# ------------------------
# Proceesing: City #  63  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hithadhoo
# ------------------------
# Proceesing: City #  64  |  Las Palmas PE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=las+palmas
# City not found, skipping...
# ------------------------
# Proceesing: City #  65  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  66  |  Pangnirtung CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pangnirtung
# ------------------------
# Proceesing: City #  67  |  Luanda AO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=luanda
# ------------------------
# Proceesing: City #  68  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ostrovnoy
# ------------------------
# Proceesing: City #  69  |  Jambi ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=jambi
# ------------------------
# Proceesing: City #  70  |  Cervo BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cervo
# ------------------------
# Proceesing: City #  71  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  72  |  San Jose de Guanipa VE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=san+jose+de+guanipa
# ------------------------
# Proceesing: City #  73  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cockburn+town
# ------------------------
# Proceesing: City #  74  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cherskiy
# ------------------------
# Proceesing: City #  75  |  Yar-Sale RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=yar-sale
# ------------------------
# Proceesing: City #  76  |  Demidov RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=demidov
# ------------------------
# Proceesing: City #  77  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  78  |  Shenjiamen CN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=shenjiamen
# ------------------------
# Proceesing: City #  79  |  Banjar ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=banjar
# ------------------------
# Proceesing: City #  80  |  Nemuro JP
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=nemuro
# ------------------------
# Proceesing: City #  81  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  82  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  83  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  84  |  Port Macquarie AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=port+macquarie
# ------------------------
# Proceesing: City #  85  |  Viedma AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=viedma
# ------------------------
# Proceesing: City #  86  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tasiilaq
# City not found, skipping...
# ------------------------
# Proceesing: City #  87  |  Sijunjung ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sijunjung
# ------------------------
# Proceesing: City #  88  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=iqaluit
# ------------------------
# Proceesing: City #  89  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: City #  90  |  Malanje AO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=malanje
# ------------------------
# Proceesing: City #  91  |  Tandalti SD
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tandalti
# ------------------------
# Proceesing: City #  92  |  Saint-Augustin FR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=saint-augustin
# ------------------------
# Proceesing: City #  93  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=bredasdorp
# City not found, skipping...
# ------------------------
# Proceesing: City #  94  |  Biak ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=biak
# ------------------------
# Proceesing: City #  95  |  Kieta PG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kieta
# ------------------------
# Proceesing: City #  96  |  Port Augusta AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=port+augusta
# ------------------------
# Proceesing: City #  97  |  Kenai US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kenai
# ------------------------
# Proceesing: City #  98  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  99  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kaitangata
# City not found, skipping...
# ------------------------
# Proceesing: City #  100  |  Agua Verde MX
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=agua+verde
# ------------------------
# Proceesing: City #  101  |  Ariogala LT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ariogala
# ------------------------
# Proceesing: City #  102  |  San Quintin PH
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=san+quintin
# ------------------------
# Proceesing: City #  103  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  104  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: City #  105  |  Gazojak TM
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=gazojak
# ------------------------
# Proceesing: City #  106  |  Yola NG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=yola
# City not found, skipping...
# ------------------------
# Proceesing: City #  107  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  108  |  Kaeo NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kaeo
# ------------------------
# Proceesing: City #  109  |  Aliwal North ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=aliwal+north
# ------------------------
# Proceesing: City #  110  |  Meihekou CN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=meihekou
# ------------------------
# Proceesing: City #  111  |  Tuy Hoa VN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tuy+hoa
# ------------------------
# Proceesing: City #  112  |  Khani GE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=khani
# City not found, skipping...
# ------------------------
# Proceesing: City #  113  |  Uglegorsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=uglegorsk
# ------------------------
# Proceesing: City #  114  |  Alvdal NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=alvdal
# ------------------------
# Proceesing: City #  115  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=lavrentiya
# ------------------------
# Proceesing: City #  116  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=port+elizabeth
# ------------------------
# Proceesing: City #  117  |  Covington US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=covington
# ------------------------
# Proceesing: City #  118  |  Phan Thiet VN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=phan+thiet
# City not found, skipping...
# ------------------------
# Proceesing: City #  119  |  Shemgang BT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=shemgang
# ------------------------
# Proceesing: City #  120  |  Kolochava UA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kolochava
# ------------------------
# Proceesing: City #  121  |  Harper US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=harper
# ------------------------
# Proceesing: City #  122  |  Sabha LY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sabha
# City not found, skipping...
# ------------------------
# Proceesing: City #  123  |  Waipawa NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=waipawa
# ------------------------
# Proceesing: City #  124  |  Teya MX
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=teya
# City not found, skipping...
# ------------------------
# Proceesing: City #  125  |  Katangli RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=katangli
# City not found, skipping...
# ------------------------
# Proceesing: City #  126  |  Narsaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=narsaq
# ------------------------
# Proceesing: City #  127  |  Hojai IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hojai
# ------------------------
# Proceesing: City #  128  |  Sioux Lookout CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sioux+lookout
# ------------------------
# Proceesing: City #  129  |  Kargasok RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kargasok
# ------------------------
# Proceesing: City #  130  |  Arman RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=arman
# ------------------------
# Proceesing: City #  131  |  Santo Antonio do Sudoeste BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=santo+antonio+do+sudoeste
# ------------------------
# Proceesing: City #  132  |  Los Llanos de Aridane ES
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=los+llanos+de+aridane
# ------------------------
# Proceesing: City #  133  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  134  |  Ahipara NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ahipara
# ------------------------
# Proceesing: City #  135  |  Coahuayana MX
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=coahuayana
# ------------------------
# Proceesing: City #  136  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=geraldton
# City not found, skipping...
# ------------------------
# Proceesing: City #  137  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sitka
# ------------------------
# Proceesing: City #  138  |  Ancud CL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ancud
# ------------------------
# Proceesing: City #  139  |  Tromso NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tromso
# ------------------------
# Proceesing: City #  140  |  Ambulu ID
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ambulu
# ------------------------
# Proceesing: City #  141  |  Sao Joao da Barra BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sao+joao+da+barra
# ------------------------
# Proceesing: City #  142  |  Te Anau NZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=te+anau
# ------------------------
# Proceesing: City #  143  |  Itarema BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=itarema
# ------------------------
# Proceesing: City #  144  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  145  |  Zalari RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=zalari
# ------------------------
# Proceesing: City #  146  |  Flin Flon CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=flin+flon
# City not found, skipping...
# ------------------------
# Proceesing: City #  147  |  Schneverdingen DE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=schneverdingen
# ------------------------
# Proceesing: City #  148  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  149  |  Kvareli GE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kvareli
# ------------------------
# Proceesing: City #  150  |  Longyearbyen NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=longyearbyen
# ------------------------
# Proceesing: City #  151  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: City #  152  |  Northam GB
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=northam
# ------------------------
# Proceesing: City #  153  |  Terney RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=terney
# ------------------------
# Proceesing: City #  154  |  Haicheng CN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=haicheng
# ------------------------
# Proceesing: City #  155  |  Poros TR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=poros
# ------------------------
# Proceesing: City #  156  |  Kuntaur GM
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kuntaur
# ------------------------
# Proceesing: City #  157  |  Ambilobe MG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ambilobe
# City not found, skipping...
# ------------------------
# Proceesing: City #  158  |  Tautira PF
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tautira
# ------------------------
# Proceesing: City #  159  |  Emerald AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=emerald
# ------------------------
# Proceesing: City #  160  |  Pyay MM
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pyay
# ------------------------
# Proceesing: City #  161  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pevek
# ------------------------
# Proceesing: City #  162  |  Panaba MX
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=panaba
# ------------------------
# Proceesing: City #  163  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  164  |  Leh IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=leh
# ------------------------
# Proceesing: City #  165  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  166  |  Bolobo CD
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=bolobo
# ------------------------
# Proceesing: City #  167  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  168  |  Aykhal RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=aykhal
# ------------------------
# Proceesing: City #  169  |  Salalah OM
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=salalah
# ------------------------
# Proceesing: City #  170  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  171  |  Vestmanna FO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=vestmanna
# City not found, skipping...
# ------------------------
# Proceesing: City #  172  |  Zhemtala RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=zhemtala
# ------------------------
# Proceesing: City #  173  |  Biograd na Moru HR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=biograd+na+moru
# ------------------------
# Proceesing: City #  174  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=east+london
# City not found, skipping...
# ------------------------
# Proceesing: City #  175  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  176  |  Nome US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=nome
# ------------------------
# Proceesing: City #  177  |  Kattivakkam IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kattivakkam
# ------------------------
# Proceesing: City #  178  |  Ciudad Bolivar VE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ciudad+bolivar
# ------------------------
# Proceesing: City #  179  |  Wewak PG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=wewak
# ------------------------
# Proceesing: City #  180  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: City #  181  |  Fairbanks US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=fairbanks
# ------------------------
# Proceesing: City #  182  |  Kavieng PG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kavieng
# ------------------------
# Proceesing: City #  183  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ilulissat
# ------------------------
# Proceesing: City #  184  |  Biltine TD
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=biltine
# ------------------------
# Proceesing: City #  185  |  Yarmouth GB
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=yarmouth
# ------------------------
# Proceesing: City #  186  |  Espeland NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=espeland
# ------------------------
# Proceesing: City #  187  |  Sao Filipe CV
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sao+filipe
# ------------------------
# Proceesing: City #  188  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: City #  189  |  Alofi NU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=alofi
# ------------------------
# Proceesing: City #  190  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=fortuna
# ------------------------
# Proceesing: City #  191  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  192  |  Barra dos Coqueiros BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=barra+dos+coqueiros
# ------------------------
# Proceesing: City #  193  |  Rock Sound BS
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=rock+sound
# ------------------------
# Proceesing: City #  194  |  Mwingi KE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mwingi
# ------------------------
# Proceesing: City #  195  |  Carballo ES
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=carballo
# ------------------------
# Proceesing: City #  196  |  Sola NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sola
# ------------------------
# Proceesing: City #  197  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=san+patricio
# ------------------------
# Proceesing: City #  198  |  Flinders AU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=flinders
# ------------------------
# Proceesing: City #  199  |  College US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=college
# ------------------------
# Proceesing: City #  200  |  Talnakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=talnakh
# ------------------------
# Proceesing: City #  201  |  Kulachi PK
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kulachi
# ------------------------
# Proceesing: City #  202  |  Camacha PT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=camacha
# ------------------------
# Proceesing: City #  203  |  Rawson AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=rawson
# ------------------------
# Proceesing: City #  204  |  Sindor RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=sindor
# ------------------------
# Proceesing: City #  205  |  Beyneu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=beyneu
# ------------------------
# Proceesing: City #  206  |  Santiago CL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=santiago
# ------------------------
# Proceesing: City #  207  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: City #  208  |  Ukiah US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ukiah
# ------------------------
# Proceesing: City #  209  |  Basoko CD
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=basoko
# ------------------------
# Proceesing: City #  210  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=portland
# ------------------------
# Proceesing: City #  211  |  Touros BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=touros
# ------------------------
# Proceesing: City #  212  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: City #  213  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  214  |  Takoradi GH
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=takoradi
# City not found, skipping...
# ------------------------
# Proceesing: City #  215  |  Kamaishi JP
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kamaishi
# ------------------------
# Proceesing: City #  216  |  Tura IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tura
# ------------------------
# Proceesing: City #  217  |  Poronaysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=poronaysk
# City not found, skipping...
# ------------------------
# Proceesing: City #  218  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: City #  219  |  Saint-Paul FR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=saint-paul
# ------------------------
# Proceesing: City #  220  |  Pandan PH
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pandan
# City not found, skipping...
# ------------------------
# Proceesing: City #  221  |  Arras FR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=arras
# ------------------------
# Proceesing: City #  222  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  223  |  Do Gonbadan IR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=do+gonbadan
# ------------------------
# Proceesing: City #  224  |  Carmelo UY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=carmelo
# ------------------------
# Proceesing: City #  225  |  Tambun MY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tambun
# ------------------------
# Proceesing: City #  226  |  Neuquen AR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=neuquen
# ------------------------
# Proceesing: City #  227  |  Pincher Creek CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pincher+creek
# ------------------------
# Proceesing: City #  228  |  Abnub EG
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=abnub
# ------------------------
# Proceesing: City #  229  |  Jinchang CN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=jinchang
# ------------------------
# Proceesing: City #  230  |  Minamiashigara JP
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=minamiashigara
# City not found, skipping...
# ------------------------
# Proceesing: City #  231  |  Ilebo CD
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ilebo
# ------------------------
# Proceesing: City #  232  |  Mandalgovi MN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mandalgovi
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  233  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  234  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  235  |  Jacareacanga BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=jacareacanga
# ------------------------
# Proceesing: City #  236  |  Piacabucu BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=piacabucu
# ------------------------
# Proceesing: City #  237  |  Balsas BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=balsas
# ------------------------
# Proceesing: City #  238  |  Cayenne GF
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cayenne
# ------------------------
# Proceesing: City #  239  |  Quatre Cocos MU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=quatre+cocos
# ------------------------
# Proceesing: City #  240  |  Vizinga RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=vizinga
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  241  |  Kota Tinggi MY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kota+tinggi
# ------------------------
# Proceesing: City #  242  |  Inhambane MZ
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=inhambane
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  243  |  Qaqortoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=qaqortoq
# City not found, skipping...
# ------------------------
# Proceesing: City #  244  |  Hatillo PR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=hatillo
# City not found, skipping...
# ------------------------
# Proceesing: City #  245  |  Kavaratti IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kavaratti
# ------------------------
# Proceesing: City #  246  |  Nola CF
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=nola
# ------------------------
# Proceesing: City #  247  |  Tineo ES
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tineo
# City not found, skipping...
# ------------------------
# Proceesing: City #  248  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  249  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=kahului
# ------------------------
# Proceesing: City #  250  |  Fort Nelson CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=fort+nelson
# ------------------------
# Proceesing: City #  251  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=caravelas
# ------------------------
# Proceesing: City #  252  |  Nalut LY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=nalut
# ------------------------
# Proceesing: City #  253  |  Cesvaine LV
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=cesvaine
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  254  |  Preobrazheniye RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=preobrazheniye
# ------------------------
# Proceesing: City #  255  |  Pacific Grove US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pacific+grove
# ------------------------
# Proceesing: City #  256  |  Valparaiso US
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=valparaiso
# ------------------------
# Proceesing: City #  257  |  Clyde River CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=clyde+river
# City not found, skipping...
# ------------------------
# Proceesing: City #  258  |  Mykhaylivka UA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=mykhaylivka
# City not found, skipping...
# ------------------------
# Proceesing: City #  259  |  Dharchula IN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=dharchula
# ------------------------
# Proceesing: City #  260  |  Dafeng CN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=dafeng
# ------------------------
# Proceesing: City #  261  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  262  |  Taoudenni ML
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=taoudenni
# ------------------------
# Proceesing: City #  263  |  Laguna MX
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=laguna
# ------------------------
# Proceesing: City #  264  |  Matagalpa NI
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=matagalpa
# ------------------------
# Proceesing: City #  265  |  Puerto Narino CO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=puerto+narino
# ------------------------
# Proceesing: City #  266  |  Ajdabiya LY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=ajdabiya
# City not found, skipping...
# ------------------------
# Proceesing: City #  267  |  Tanah Merah MY
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=tanah+merah
# ------------------------
# Proceesing: City #  268  |  Berlevag NO
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=berlevag
# ------------------------
# Proceesing: City #  269  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: City #  270  |  Portneuf CA
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=portneuf
# ------------------------
# Proceesing: City #  271  |  Dakar SN
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=dakar
# ------------------------
# Proceesing: City #  272  |  Marienburg DE
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=marienburg
# ------------------------
# Proceesing: City #  273  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=leningradskiy
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 51] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x11fa90b70>: Failed to establish a new connection: [Errno 51] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='api.openweathermap.org', port=80): Max retries exceeded with url: /data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pio+xii (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x11fa90b70>: Failed to establish a new connection: [Errno 51] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-3a013cbccbe4> in <module>
#      14     target_city = row["City"]
#      15     target_url = url + "appid=" + "ec8ce9ae3ae7d672b2fe520eb9895eed" + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
# ---> 16     city_data = requests.get(target_url).json()
#      17     if city_data["cod"] == "404":
#      18         print("City not found, skipping...")
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.openweathermap.org', port=80): Max retries exceeded with url: /data/2.5/weather?appid=ec8ce9ae3ae7d672b2fe520eb9895eed&units=IMPERIAL&q=pio+xii (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x11fa90b70>: Failed to establish a new connection: [Errno 51] Network is unreachable'))
